# %%
import matplotlib.pyplot as plt

# Definir variables y valores
dias = ["Lunes 9/10", "Martes 10/10", "Miércoles 11/10", "Jueves 12/10", "Viernes 13/10"]
calorias_por_dia = [1868, 1727, 1745, 1345, 1861]
calorias_ejercicio_activo = [496, 378, 384, 0, 502]
calorias_ejercicio_total = [523, 420, 465, 0, 533]

# Seleccionar de qué ancho van a ser las barras
bar_width = 0.25

# Crear el gráfico de barras, agregando color a cada variable. Como ponemos más de una variable que va en función de X, utilizamos la variable "i" para desplazar las barras
plt.bar(x, calorias_por_dia, width=bar_width, label='Calorias por día', color='blue')
plt.bar([i + bar_width for i in x], calorias_ejercicio_activo, width=bar_width, label='Calorias en ejercicio activo', color='yellow')
plt.bar([i + 2 * bar_width for i in x], calorias_ejercicio_total, width=bar_width, label='Calorias en ejercicio total', color='red')

# Personalizar el gráfico
plt.xlabel('Días')
plt.ylabel('Calorias')
plt.title('Calorias quemadas por día')

#Asignamos una etiqueta que muestre a qué corresponde cada color
plt.xticks([i + bar_width for i in x], dias)
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()
